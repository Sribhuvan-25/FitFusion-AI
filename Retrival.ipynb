# %%
import os
import pandas as pd
import openai
import pinecone
from tqdm.notebook import tqdm

# %%
"""
    Generates a high-dimensional embedding for the given text using OpenAI's embedding model.

    Parameters:
        text: Input text to embed.
        model: Embedding model name (default is "text-embedding-3-small").

    Returns:
        A list representing the embedding vector.
 """
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

# %%
pc = pinecone.Pinecone(api_key=pinecone_api_key)
index = pc.Index("gen-fit")
messages = []

# %%
# Example query text
query_text = "Want to know about replacements for sugar"

# Generate embedding for the query
query_embedding = get_embedding(query_text)

# %%
# Example query text
# query_text = "Want to know about replacements for sugar"

# Generate embedding for the query
# query_embedding = get_embedding(query_text)

"""
    Retrieves the top 5 matching documents from the Pinecone index using the query embedding.

    Parameters:
        query_embedding: The embedding vector of the user query.

    Returns:
        A dictionary containing the top matching documents and their metadata.
"""
def retrieve_documents(query_embedding):

    # Query Pinecone index
    results = index.query(
    vector=query_embedding,
    top_k=5,
    include_metadata=True
    )

    # Display the results
    for match in results['matches']:
        print(f"Score: {match['score']}")
        print(f"Title: {match['metadata']['Topic']}")
        print(f"Content: {match['metadata']['Content']}\n")
    
    return results

# %%
"""
    Generates a prompt for the GPT model using the top retrieved documents and the original query.

    Parameters:
        documents: The retrieved documents from Pinecone, including metadata.
        original_query: The user's original query.

    Returns:
        A formatted string prompt containing the query and summarized document content.
"""


def generate_prompt(documents, original_query):
    document_texts = []
    for i, match in enumerate(documents['matches'][:3]):
        doc_text = match['metadata'].get('Content', '')
        document_texts.append(f"Document {i+1}: {doc_text}")

    prompt = (
        f"The user's query is: '{original_query}'\n\n"
        "Based on the following documents, answer the users query" +
        "\n".join(document_texts) +
        f"\n\nPlease provide a response in a conversational format. Give response under 300 tokens" +
        "Give the response as a small paragrah"
    )
    return prompt

# %%
"""
    Generates a conversational response using GPT-4 based on the provided prompt.

    Parameters:
        prompt: The formatted string prompt containing the query and document context.

    Returns:
        The generated response as a string.
"""


def get_response(prompt):
    messages.append({"role": "user", "content": prompt})
    response = openai.chat.completions.create(
        model='gpt-4', 
        messages=messages,
        max_tokens=1200,
        n=1,
        temperature=0.7,
    )
    questions = response.choices[0].message.content
    messages.append({"role": "assistant", "content": questions})
    return questions

# %%
"""
    Handles the entire query processing pipeline by generating an embedding for the query, 
    retrieving relevant documents, creating a prompt, and generating a conversational response.
    
    Additionally, calculates relevance score and response time for evaluation, with detailed timing 
    for individual steps.

    Parameters:
        query: The user's input query as a string.
"""

import time
from sklearn.metrics.pairwise import cosine_similarity

def process_query(query):
   
    embedding_start_time = time.time()
    query_embedding = get_embedding(query)
    embedding_end_time = time.time()

    if query_embedding is None:
        print("Failed to generate embedding for the query.")
        return
    
    # Calculate time for Query Embedding Generation
    embedding_time = embedding_end_time - embedding_start_time

    retrieval_start_time = time.time()
    results = retrieve_documents(query_embedding)
    retrieval_end_time = time.time()

    if not results['matches']:
        print("No documents were retrieved.")
        return
    
    # Calculate time for Document Retrieval
    retrieval_time = retrieval_end_time - retrieval_start_time

    response_start_time = time.time()
    prompt = generate_prompt(results, query)
    get_response_ans = get_response(prompt)
    response_end_time = time.time()

    # Calculate time for Response Generation
    response_time = response_end_time - response_start_time

    # Calculate relevance score
    response_embedding = get_embedding(get_response_ans)
    relevance_score = cosine_similarity([query_embedding], [response_embedding])[0][0]

    # Total latency calculation
    total_latency = embedding_time + retrieval_time + response_time

    print("\n=== User's Query ===")
    print(query)
    print(f"\n=== Generated Response ===")
    print(get_response_ans)
    print(f"\n=== Metrics ===")
    print(f"Relevance Score: {relevance_score:.2f}")
    print(f"Query Embedding Generation Time: {embedding_time:.2f} seconds")
    print(f"Document Retrieval Time: {retrieval_time:.2f} seconds")
    print(f"Response Generation Time: {response_time:.2f} seconds")
    print(f"Total Response Time (Latency): {total_latency:.2f} seconds")

# %%
query = input("Enter your query: ")
process_query(query)
# Out:
# Score: 0.475393802
# Title: Get them active
# Content: exercis keep us healthi less like get sick children realli activ hour day activ doesnt mean play sport go gym could play playground go walk necessarili better child seriou athlet exercis sever hour day make sure exercis isnt eat sleep caus burnout could caus problem immun system
#
# Score: 0.429633439
# Title: Sample calisthenics workout
# Content: tri exercis part calisthen routin train strength aim eight 12 repetit rep cannot rep first gradual increas rep improv beginn start one set rep work three set develop strength rest 30 90 second set start positionstand straight feet togeth movementlift right knee high comfort touch hand knee lower leg repeat left knee one rep start positionstand feet shoulderwidth apart arm side movementslowli bend hip knee lower buttock eight inch your sit back chair let arm swing forward help balanc keep spine neutral hold slowli return start posit start positionkneel four hand shoulderwidth apart walk hand forward lower hip bodi 45° angl floor form straight line head knee movementbend elbow side slowli lower upper bodi toward floor elbow bent 90° press floor straighten arm return start posit make harderlift knee floor pushup support hand toe ball feet start positionstand straight feet togeth arm side movementstep side left foot keep right foot place left foot hit ground transfer weight left leg hing forward hip bend left knee lower lung keep right leg straight put hand left thigh support press left foot stand back shift weight onto right foot rais left knee hip level get balanc step left leg anoth lung continu 30 second repeat sequenc step right 30 second start positionkneel four hand knee directli align shoulder hip extend leg feet flex toe touch floor balanc palm toe ball feet like top posit pushup plank movementtighten abdomin muscl lower knee toward floor extend leg return plank posit
#
# Score: 0.423758715
# Title: How much exercise do I need?
# Content: much exercis get depend sever factor includ current level fit fit goal type exercis you’r plan whether deficit area strength flexibl balanc gener rule 150 minut moder intens aerob activ 75 minut vigor exercis recommend weekli minimum becom fit you’ll want exceed order reap maximum benefit natur way split 150 minut might 30minut session five time per week break two 15minut session singl day adopt whatev schedul fit lifestyl strength exercis aim work major muscl group twice three time week leav 48 hour workout recoveri “totalbody” workout that’ two session per week choos split workout target specif muscl group eg “leg day” requir frequent workout make sure you’r leav 48 hour rest rework major muscl notic problem balanc unsteadi dizzi vertigo talk healthcar provid recommend balancespecif exercis get three halfhour workout week addit 30minut walk least twice weekli it’ best stretch warm minut perform stretch exercis complet workout stretch muscl group take slow steadi releas repeat much exercis much expect littl muscl sore workout especi begin find bodi simpli recov workout may overtrain rememb senior need recoveri time younger peopl except “welcome” muscl sore exercis program make feel good doesn’t you’r probabl overdo doesn’t mean quit dial back intens frequenc workout hit “sweet spot” you’v “tire out” bodi recov enough tackl next session enthusiasm
#
# Score: 0.423136652
# Title: Different kinds of aerobics
# Content: you’v probabl heard inspir success stori aboutintermitt fast fast healthi intermitt fast work fasting—abstain eat period time—i ancient practic safe taken extrem tradit benefit fast spiritu physic peopl fast religi reason often report stronger focu spiritu matter fast physic simpl fast lower blood sugar reduc inflamm improv metabol clear toxin damag cell link lower risk cancer reduc pain arthriti enhanc brain function intermitt fast mean divid one’ time “eat windows” period abstent regular basi common intermitt fast schedul might restrict eat hour 700 300 pm remain 16 hour day spent fast specif prescrib schedul peopl less gener eat window set rule eat say 800 pm—or consider less gener side allow eat everi day scienc behind intermitt fast base alter body’ metabol period without eat insulin level drop point bodi begin burn fat fuel addit think goe slow body’ metabol caus appetit drop thu consum fewer calori resum eat numer studi demonstr benefit intermitt fast weight loss howev it’ clear effect simpli restrict calori follow normal eat schedul one possibl reason success intermitt fast practition quit habit eat late even night hour restrict eat earlier day align better bodies’ circadian rhythm less like caus us store food fat cell sinc intermitt fast difficult mani peopl adher wise altern might consum lowcalori mediterranean diet stop day’ eat late afternoon certain peopl tri intermitt fast without first check doctor diabet heart diseas intermitt fast “lifestyleintensive” dietari pattern mean challeng maintain face normal social relationship rest famili eat you’r fast might tempt indulg surrend familym ritual job requir dine client colleagu you’ll find intermitt fast schedul difficult maintain rememb best healthi eat plan one you’ll stick
#
#
# === User's Query ===
# Diet plan for older people
#
# === Generated Response ===
# Based on the documents provided, a healthy diet plan for older people should emphasize natural, unprocessed foods. The Mediterranean style diet is often recommended as it includes minimally processed fruits, vegetables, legumes, nuts, and whole grains, with moderate amounts of yogurt, cheese, poultry, and fish. Olive oil is the primary cooking fat and red meat and added sugars are eaten sparingly. The DASH diet is also beneficial as it is low in cholesterol and saturated fats and high in magnesium, calcium, fiber, and potassium. It also includes whole grains, vegetables, fruits, fish, poultry, nuts, and olive oil. A healthy diet also includes a good balance of nutrients, plenty of plant-based foods, low sugar and salt, and healthy fats. It's important to remember, the best diet is one that can be maintained in the long term, and it's always recommended to consult with a healthcare provider before starting any new diet plan.
#
# === Metrics ===
# Relevance Score: 0.70
# Query Embedding Generation Time: 0.45 seconds
# Document Retrieval Time: 1.28 seconds
# Response Generation Time: 7.70 seconds
# Total Response Time (Latency): 9.44 seconds

# %%
# In case of interactive session

def generate_prompt(results, query, context=None):
    """
    Generates a prompt for GPT-4 based on retrieved documents and optional past context.

    Parameters:
        results: Retrieved documents from Pinecone.
        query: The user's current input query.
        context: Optional context containing past queries and responses.
    
    Returns:
        A string prompt to send to GPT-4.
    """
    document_texts = []
    for i, match in enumerate(results['matches'][:3]):  # Use top 3 documents
        doc_text = match['metadata'].get('Content', '')
        document_texts.append(f"Document {i+1}: {doc_text}")

    # Add past context if available
    context_text = ""
    if context and 'queries' in context and 'responses' in context:
        for i, (q, r) in enumerate(zip(context['queries'], context['responses'])):
            context_text += f"Previous Query {i+1}: {q}\nPrevious Response {i+1}: {r}\n"

    # Combine context and current query
    prompt = (
        f"The user's query is: '{query}'\n\n"
        "Based on the following documents and past context, answer the user's query:\n\n" +
        context_text + "\n".join(document_texts) +
        "\n\nPlease provide a response in a conversational format, limited to 300 tokens."
    )
    return prompt

"""
    Conversation loop for iterative queries
"""
def interactive_session():
    context = {'queries': [], 'responses': []}
    print("Welcome to the conversational query assistant. Type 'exit' to end the session.\n")
    
    while True:
        query = input("Enter your query: ")
        if query.lower() == 'exit':
            print("Exiting session. Goodbye!")
            break
        context = process_query(query, context)
